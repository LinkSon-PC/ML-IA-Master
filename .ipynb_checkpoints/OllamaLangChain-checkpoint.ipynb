# %% [markdown]
# # langchain-Ollama
#
# https://reference.langchain.com/python/langchain-ollama

# %%
# !pip install -qU langchain-ollama

# %%
import os
from langchain_ollama import ChatOllama
#from langchain_openai import ChatOpenaI

from dotenv import load_dotenv

# %%
load_dotenv()

# OLLAMA
#os.environ["LANGSMITH_TRACING"] = "true"
#os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")

## Instalation
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="llama3.2:3b",
    temperature=0.3,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='Je suis passionné de programmation.\n\n(Note: I used the informal "je" instead of the formal "je suis", as it\'s more suitable for an expression of enthusiasm and personal preference.)', additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2026-05-06T16:30:26.0334003Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8464592200, 'load_duration': 7535398300, 'prompt_eval_count': 45, 'prompt_eval_duration': 41159400, 'eval_count': 40, 'eval_duration': 783209700, 'logprobs': None, 'model_name': 'llama3.2:3b', 'model_provider': 'ollama'}, id='lc_run--019dfe20-37ce-74d0-92c9-2a512d87d6cc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 40, 'total_tokens': 85})

# %%
print(ai_msg.content)
# Out:
# Je suis passionné de programmation.
#
# (Note: I used the informal "je" instead of the formal "je suis", as it's more suitable for an expression of enthusiasm and personal preference.)

# %% [markdown]
# ## Embeddings

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="llama3.2:3b",
)

# %% [markdown]
# ### Indexing and retrieval
#
# Embedding models are often used in retrieval-augmented generation (RAG) flows, both as part of indexing data as well as later retrieving it.

# %%
# Create a vector store with a sample text
from langchain_core.vectorstores import InMemoryVectorStore

text = "LangChain is the framework for building context-aware reasoning applications"

vectorstore = InMemoryVectorStore.from_texts(
    [text],
    embedding=embeddings,
)

# Use the vectorstore as a retriever
retriever = vectorstore.as_retriever()

# Retrieve the most similar text
retrieved_documents = retriever.invoke("What is LangChain?")

# Show the retrieved document's content
print(retrieved_documents[0].page_content)
# Out:
# LangChain is the framework for building context-aware reasoning applications

# %% [markdown]
# ### Direct usage
#
# Under the hood, the vectorstore and retriever implementations are calling embeddings.embed_documents(...) and embeddings.embed_query(...) to create embeddings for the text(s) used in from_texts and retrieval invoke operations, respectively.
# You can directly call these methods to get embeddings for your own use cases.

# %% [markdown]
# ### Embed single texts
#
# You can embed single texts or documents with embed_query:

# %%
single_vector = embeddings.embed_query(text)
print(str(single_vector)[:100])  # Show the first 100 characters of the vector
# Out:
# [-0.011206772, 0.0013444128, 0.015779449, -0.020870524, -0.00065934873, -0.011599963, -0.011529305,

# %% [markdown]
# ### Embed multiple texts
#
# You can embed multiple texts with embed_documents:

# %%
text2 = (
    "LangGraph is a library for building stateful, multi-actor applications with LLMs"
)
two_vectors = embeddings.embed_documents([text, text2])
for vector in two_vectors:
    print(str(vector)[:100])  # Show the first 100 characters of the vector
# Out:
# [-0.011206772, 0.0013444128, 0.015779449, -0.020870524, -0.00065934873, -0.011599963, -0.011529305,
# [-0.0062211202, 0.0017048359, 0.004182204, -0.0042017773, -0.0015518063, -0.017028581, -0.0046905424

# %% [markdown]
# ## OllamaEmbeddings
#
# Ollama embedding model integration.
#
# Install the langchain-ollama integration package:

# %%
# !pip install -U langchain_ollama
# Out:
# Requirement already satisfied: langchain_ollama in c:\users\tonyf\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain_ollama) (1.3.3)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain_ollama) (0.6.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.8.1)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tonyf\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\tonyf\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tonyf\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.24.0)
# Requirement already satisfied: anyio in c:\users\tonyf\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (4.10.0)
# Requirement already satisfied: certifi in c:\users\tonyf\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\tonyf\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\tonyf\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\tonyf\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tonyf\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\tonyf\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\tonyf\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tonyf\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tonyf\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tonyf\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_ollama) (1.3.0)

# %%
from langchain_ollama import OllamaEmbeddings

embed = OllamaEmbeddings(model="llama3.2:3b")

# %% [markdown]
# Embed single text:

# %%
input_text = "The meaning of life is 42"
vector = embed.embed_query(input_text)
print(vector[:3])
# Out:
# [-0.00012057043, 0.009949889, 0.0055533512]

# %% [markdown]
# ### Embed multiple texts

# %%
input_texts = ["Document 1...", "Document 2..."]
vectors = embed.embed_documents(input_texts)
print(len(vectors))
# The first 3 coordinates for the first vector
print(vectors[0][:3])
# Out:
# 2
# [-0.024324564, -0.03266639, -0.022302348]

# %% [markdown]
# ### Async

# %%
vector = await embed.aembed_query(input_text)
print(vector[:3])

# multiple:
# await embed.aembed_documents(input_texts)
# Out:
# [-0.00012057043, 0.009949889, 0.0055533512]
